# %%
import csv
import pymongo
import requests

# MongoDB connection information
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
db = mongo_client["your_database_name"]

# Function to populate Baselight collection
def populate_baselight_collection(baselight_file):
    baselight_collection = db["baselight"]

    output_data = []

    for currentReadLine in baselight_file:
        parseline = currentReadLine.split()  # Split the line
        if parseline:  # Check if the list is not empty
            currentFolder = parseline.pop(0)  # Get the current folder
            parseFolder = currentFolder.split("/")  # Split current folder by "/"
            if len(parseFolder) > 1:
                parseFolder.pop(1)  # Remove the second element if exists
            newFolder = "/".join(parseFolder)  # Reconstruct the folder path
            for techfile in XY_File:
                if newFolder in techfile:
                    currentFolder = techfile.strip()
            tempStart = None
            tempLast = None
            for number in parseline:
                if not number.isdigit():
                    continue
                number = int(number)
                if tempStart is None:
                    tempStart = number
                    tempLast = number
                elif number == tempLast + 1:
                    tempLast = number
                else:
                    if tempStart == tempLast:
                        output_data.append({"folder": currentFolder, "frames": [tempStart]})
                    else:
                        output_data.append({"folder": currentFolder, "frames": list(range(tempStart, tempLast+1))})  # Concatenate range
                    tempStart = number
                    tempLast = number
            if tempStart is not None:
                if tempStart == tempLast:
                    output_data.append({"folder": currentFolder, "frames": [tempStart]})
                else:
                    output_data.append({"folder": currentFolder, "frames": list(range(tempStart, tempLast+1))})  # Concatenate range

    # Insert data into Baselight collection
    baselight_collection.insert_many(output_data)

# Function to populate Xytech collection
def populate_xytech_collection(xytech_file):
    xytech_collection = db["xytech"]

    output_data = []

    for line in xytech_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        parts = line.split()
        if len(parts) != 2:
            print(f"Ignoring invalid line in Xytech file: {line}")
            continue  # Skip lines with unexpected format
        workorder, location = parts
        output_data.append({"workorder": workorder, "location": location})

    # Insert data into Xytech collection
    xytech_collection.insert_many(output_data)


# Paths to Baselight and Xytech files
baselight_file_path = "Baselight_export.txt"
xytech_file_path = "Xytech.txt"

# Open Baselight file
with open(baselight_file_path, "r") as baselight_file:
    populate_baselight_collection(baselight_file)

# Open Xytech file
with open(xytech_file_path, "r") as xytech_file:
    populate_xytech_collection(xytech_file)

print("Collections populated successfully!")

# Downloading the video file
video_url = "https://mycsun.box.com/s/v55rwqlu5ufuc8l510r8nni0dzq5qki7"
video_filename = "my_video.mp4"

response = requests.get(video_url)
with open(video_filename, 'wb') as f:
    f.write(response.content)

print("Video downloaded successfully!")
# Out:
# Ignoring invalid line in Xytech file: Xytech Workorder 1109
# Ignoring invalid line in Xytech file: Producer: Olivia Rodrigo
# Ignoring invalid line in Xytech file: Operator: Johnny Bananas
# Ignoring invalid line in Xytech file: Location:
# Ignoring invalid line in Xytech file: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Ignoring invalid line in Xytech file: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Ignoring invalid line in Xytech file: /hpsans13/production/Dune2/reel1/VFX/Framestore
# Ignoring invalid line in Xytech file: /hpsans14/production/Dune2/reel1/VFX/AnimalLogic
# Ignoring invalid line in Xytech file: /hpsans13/production/Dune2/reel1/partB/1920x1080
# Ignoring invalid line in Xytech file: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Ignoring invalid line in Xytech file: /hpsans11/production/Dune2/pickups/shot_2b/1920x1080
# Ignoring invalid line in Xytech file: /hpsans17/production/Dune2/reel1/partC/1920x1080
# Ignoring invalid line in Xytech file: Notes:
# Ignoring invalid line in Xytech file: Please clean files noted per Colorist Brock Purdy
# Collections populated successfully!
# Video downloaded successfully!

# %%
import csv
import pymongo

# MongoDB connection information
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
db = mongo_client["your_database_name"]

# Function to populate Baselight collection
def populate_baselight_collection(baselight_file):
    baselight_collection = db["baselight"]

    output_data = []

    for line in baselight_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        parts = line.split()
        folder = parts[0]
        frames = [int(frame) for frame in parts[1:] if frame.isdigit()]
        output_data.append({"folder": folder, "frames": frames})

    # Insert data into Baselight collection
    baselight_collection.insert_many(output_data)

def populate_xytech_collection(xytech_file):
    xytech_collection = db["xytech"]

    output_data = []

    workorder = None
    location = []
    notes = []

    for line in xytech_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        if line.startswith("Xytech Workorder"):
            if workorder is not None:  # Save previous data if any
                output_data.append({"workorder": workorder, "location": location, "notes": "\n".join(notes)})
                location = []  # Reset location for next entry
                notes = []  # Reset notes for next entry
            workorder = line.split()[-1]  # Extract workorder number
        elif line.startswith("Location:"):
            continue  # Skip Location: line
        elif line.startswith("Notes:"):
            continue  # Skip Notes: line
        else:
            # Assume it's a location path or a note
            if line.startswith("/"):  # Check if it's a location path
                location.append(line)  # Add to location list
            else:
                notes.append(line)  # Add to notes list

    # Save the last entry after loop ends
    if workorder is not None:
        output_data.append({"workorder": workorder, "location": location, "notes": "\n".join(notes)})

    # Insert data into Xytech collection
    xytech_collection.insert_many(output_data)


# Paths to Baselight and Xytech files
baselight_file_path = "Baselight_export.txt"
xytech_file_path = "Xytech.txt"

# Open Baselight file
with open(baselight_file_path, "r") as baselight_file:
    populate_baselight_collection(baselight_file)

# Open Xytech file
with open(xytech_file_path, "r") as xytech_file:
    populate_xytech_collection(xytech_file)

print("Collections populated successfully!")
# Out:
# Collections populated successfully!

# %%
import csv
import pymongo

# MongoDB connection information
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
db = mongo_client["your_database_name"]

# Function to populate Baselight collection
def populate_baselight_collection(baselight_file):
    baselight_collection = db["baselight"]

    output_data = []

    for line in baselight_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        parts = line.split()
        folder = parts[0]
        frames = [int(frame) for frame in parts[1:] if frame.isdigit()]
        output_data.append({"folder": folder, "frames": frames})

    # Insert data into Baselight collection
    baselight_collection.insert_many(output_data)

def populate_xytech_collection(xytech_file):
    xytech_collection = db["xytech"]

    output_data = []

    workorder = None
    location = []
    notes = []

    for line in xytech_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        if line.startswith("Xytech Workorder"):
            if workorder is not None:  # Save previous data if any
                output_data.append({"workorder": workorder, "location": location, "notes": "\n".join(notes)})
                location = []  # Reset location for next entry
                notes = []  # Reset notes for next entry
            workorder = line.split()[-1]  # Extract workorder number
        elif line.startswith("Location:"):
            continue  # Skip Location: line
        elif line.startswith("Notes:"):
            continue  # Skip Notes: line
        else:
            # Assume it's a location path or a note
            if line.startswith("/"):  # Check if it's a location path
                location.append(line)  # Add to location list
            else:
                notes.append(line)  # Add to notes list

    # Save the last entry after loop ends
    if workorder is not None:
        output_data.append({"workorder": workorder, "location": location, "notes": "\n".join(notes)})

    # Insert data into Xytech collection
    xytech_collection.insert_many(output_data)


    
def process_collections():
    # Query the database for Baselight collections
    baselight_collection = db["baselight"]
    cursor = baselight_collection.find({}, {"_id": 0, "folder": 1, "frames": 1})

    # Process each document in the collection
    for document in cursor:
        location = document["folder"]
        frames = document["frames"]
        print(f"Location: {location}")
        print("Frames to fix:")
        if len(frames) == 1:
            print(frames[0])
        else:
            frame_ranges = []
            start_frame = frames[0]
            end_frame = frames[0]
            for frame in frames[1:]:
                if frame == end_frame + 1:
                    end_frame = frame
                else:
                    if start_frame == end_frame:
                        frame_ranges.append(str(start_frame))
                    else:
                        frame_ranges.append(f"{start_frame}-{end_frame}")
                    start_frame = frame
                    end_frame = frame
            if start_frame == end_frame:
                frame_ranges.append(str(start_frame))
            else:
                frame_ranges.append(f"{start_frame}-{end_frame}")
            print(", ".join(frame_ranges))
        print()

# Paths to Baselight and Xytech files
baselight_file_path = "Baselight_export.txt"
xytech_file_path = "Xytech.txt"

# Open Baselight file
with open(baselight_file_path, "r") as baselight_file:
    populate_baselight_collection(baselight_file)

# Open Xytech file
with open(xytech_file_path, "r") as xytech_file:
    populate_xytech_collection(xytech_file)

process_collections()
print("Collections populated successfully!")
# Out:
# Location: /baselightfilesystem1/Dune2/reel1/partA/1920x1080
# Frames to fix:
# 2-4, 31-33, 67-70, 122-123, 155, 1023, 1111-1112, 1160, 1201-1205, 1211-1215
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Hydraulx
# Frames to fix:
# 1251-1253, 1260, 1270-1272
#
# Location: /baselightfilesystem1/Dune2/reel1/partA/1920x1080
# Frames to fix:
# 1302-1303, 1310, 1500, 5000-5002
#
# Location: /baselightfilesystem1/Dune2/pickups/shot_1ab/1920x1080
# Frames to fix:
# 5010-5014
#
# Location: /baselightfilesystem1/Dune2/reel1/partA/1920x1080
# Frames to fix:
# 5111, 5122, 5133, 5144, 5155, 5166
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Framestore
# Frames to fix:
# 6188-6191
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Hydraulx
# Frames to fix:
# 6197-6199
#
# Location: /baselightfilesystem1/Dune2/reel1/partA/1920x1080
# Frames to fix:
# 6200-6201, 6209, 6212, 6219, 6233-6234, 6267, 6269, 6271, 6278, 6282, 6288-6290, 6292-6294
#
# Location: /baselightfilesystem1/Dune2/reel1/partB/1920x1080
# Frames to fix:
# 6409-6411, 6413, 6450, 6666-6668, 6670-6671, 6680-6684
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/AnimalLogic
# Frames to fix:
# 6832-6834, 6911-6914
#
# Location: /baselightfilesystem1/Dune2/reel1/partB/1920x1080
# Frames to fix:
# 8845
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Hydraulx
# Frames to fix:
# 8846
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Framestore
# Frames to fix:
# 8847
#
# Location: /baselightfilesystem1/Dune2/pickups/shot_2b/1920x1080
# Frames to fix:
# 10001-10002, 10008, 11113
#
# Location: /baselightfilesystem1/Dune2/reel1/partB/1920x1080
# Frames to fix:
# 12011, 12021, 12031, 12041, 12051, 12111, 12121, 12131, 12141, 12200, 12211
#
# Location: /baselightfilesystem1/Dune2/reel1/partA/1920x1080
# Frames to fix:
# 2-4, 31-33, 67-70, 122-123, 155, 1023, 1111-1112, 1160, 1201-1205, 1211-1215
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Hydraulx
# Frames to fix:
# 1251-1253, 1260, 1270-1272
#
# Location: /baselightfilesystem1/Dune2/reel1/partA/1920x1080
# Frames to fix:
# 1302-1303, 1310, 1500, 5000-5002
#
# Location: /baselightfilesystem1/Dune2/pickups/shot_1ab/1920x1080
# Frames to fix:
# 5010-5014
#
# Location: /baselightfilesystem1/Dune2/reel1/partA/1920x1080
# Frames to fix:
# 5111, 5122, 5133, 5144, 5155, 5166
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Framestore
# Frames to fix:
# 6188-6191
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Hydraulx
# Frames to fix:
# 6197-6199
#
# Location: /baselightfilesystem1/Dune2/reel1/partA/1920x1080
# Frames to fix:
# 6200-6201, 6209, 6212, 6219, 6233-6234, 6267, 6269, 6271, 6278, 6282, 6288-6290, 6292-6294
#
# Location: /baselightfilesystem1/Dune2/reel1/partB/1920x1080
# Frames to fix:
# 6409-6411, 6413, 6450, 6666-6668, 6670-6671, 6680-6684
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/AnimalLogic
# Frames to fix:
# 6832-6834, 6911-6914
#
# Location: /baselightfilesystem1/Dune2/reel1/partB/1920x1080
# Frames to fix:
# 8845
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Hydraulx
# Frames to fix:
# 8846
#
# Location: /baselightfilesystem1/Dune2/reel1/VFX/Framestore
# Frames to fix:
# 8847
#
# Location: /baselightfilesystem1/Dune2/pickups/shot_2b/1920x1080
# Frames to fix:
# 10001-10002, 10008, 11113
#
# Location: /baselightfilesystem1/Dune2/reel1/partB/1920x1080
# Frames to fix:
# 12011, 12021, 12031, 12041, 12051, 12111, 12121, 12131, 12141, 12200, 12211
#
# Collections populated successfully!

# %%
import csv
import pymongo
import argparse
import subprocess

# MongoDB connection information
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
db = mongo_client["your_database_name"]

# Function to populate Baselight collection
def populate_baselight_collection(baselight_file):
    baselight_collection = db["baselight"]

    output_data = []

    for line in baselight_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        parts = line.split()
        folder = parts[0]
        frames = [int(frame) for frame in parts[1:] if frame.isdigit()]
        output_data.append({"folder": folder, "frames": frames})

    # Insert data into Baselight collection
    baselight_collection.insert_many(output_data)

def populate_xytech_collection(xytech_file):
    xytech_collection = db["xytech"]

    output_data = []

    workorder = None
    location = []
    notes = []

    for line in xytech_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        if line.startswith("Xytech Workorder"):
            if workorder is not None:  # Save previous data if any
                output_data.append({"workorder": workorder, "location": location, "notes": "\n".join(notes)})
                location = []  # Reset location for next entry
                notes = []  # Reset notes for next entry
            workorder = line.split()[-1]  # Extract workorder number
        elif line.startswith("Location:"):
            continue  # Skip Location: line
        elif line.startswith("Notes:"):
            continue  # Skip Notes: line
        else:
            # Assume it's a location path or a note
            if line.startswith("/"):  # Check if it's a location path
                location.append(line)  # Add to location list
            else:
                notes.append(line)  # Add to notes list

    # Save the last entry after loop ends
    if workorder is not None:
        output_data.append({"workorder": workorder, "location": location, "notes": "\n".join(notes)})

    # Insert data into Xytech collection
    xytech_collection.insert_many(output_data)


#proj1 script
def process_collections():
    # Query the database for Baselight collections
    baselight_collection = db["baselight"]
    cursor = baselight_collection.find({}, {"_id": 0, "folder": 1, "frames": 1})

    # Process each document in the Baselight collection
    for document in cursor:
        currentFolder = document["folder"]
        parseline = [str(frame) for frame in document["frames"]]  # Convert frames to strings

        parseFolder = currentFolder.split("/")  # Split current folder by "/"
        if len(parseFolder) > 1:
            parseFolder.pop(1)  # Remove the second element if exists
        newFolder = "/".join(parseFolder)  # Reconstruct the folder path

        for techfile in XY_File:
            if newFolder in techfile:
                currentFolder = techfile.strip()

        tempStart = None
        tempLast = None
        for number in parseline:
            if not number.isdigit():
                continue
            number = int(number)
            if tempStart is None:
                tempStart = number
                tempLast = number
            elif number == tempLast + 1:
                tempLast = number
            else:
                if tempStart == tempLast:
                    print(f"Location: {currentFolder}")
                    print("Frames to fix:")
                    print(tempStart)
                else:
                    print(f"Location: {currentFolder}")
                    print("Frames to fix:")
                    print(f"{tempStart}-{tempLast}")
                tempStart = number
                tempLast = number
        if tempStart is not None:
            if tempStart == tempLast:
                print(f"Location: {currentFolder}")
                print("Frames to fix:")
                print(tempStart)
            else:
                print(f"Location: {currentFolder}")
                print("Frames to fix:")
                print(f"{tempStart}-{tempLast}")

# Function to get video duration using ffmpeg
def get_video_duration(video_file):
    command = ['ffmpeg', '-i', video_file, '-v', 'error', '-show_entries', 'format=duration', '-of', 'default=noprint_wrappers=1:nokey=1']
    output = subprocess.check_output(command).decode('utf-8').strip()
    return float(output)

# Function to process collections
def process_collectionsVideo(video_file):
    # Get video duration
    video_duration = get_video_duration(video_file)

    # Query the database for Baselight collections
    baselight_collection = db["baselight"]
    cursor = baselight_collection.find({}, {"_id": 0, "folder": 1, "frames": 1})

    # Process each document in the Baselight collection
    for document in cursor:
        currentFolder = document["folder"]
        frames = document["frames"]

        # Filter frames based on video duration
        valid_frames = []
        for frame_range in frames:
            if isinstance(frame_range, int):
                if frame_range < video_duration:
                    valid_frames.append(frame_range)
            else:
                start_frame, end_frame = map(int, frame_range.split('-'))
                if start_frame < video_duration:
                    valid_frames.append(frame_range)

        # Print valid frames for current folder
        print(f"Location: {currentFolder}")
        print("Valid Frames to fix:", valid_frames)
        print()

    video.close()

# Paths to Baselight and Xytech files
baselight_file_path = "Baselight_export.txt"
xytech_file_path = "Xytech.txt"
video_file_path = "twitch_nft_demo.mp4"

# Open Baselight file
with open(baselight_file_path, "r") as baselight_file:
    populate_baselight_collection(baselight_file)

# Open Xytech file
with open(xytech_file_path, "r") as xytech_file:
    populate_xytech_collection(xytech_file)
    
process_collectionsVideo(video_file_path)
process_collections()
print("Collections populated successfully!")
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[29], line 169
#     166 with open(xytech_file_path, "r") as xytech_file:
#     167     populate_xytech_collection(xytech_file)
# --> 169 process_collectionsVideo(video_file_path)
#     170 process_collections()
#     171 print("Collections populated successfully!")
#
# Cell In[29], line 127, in process_collectionsVideo(video_file)
#     125 def process_collectionsVideo(video_file):
#     126     # Get video duration
# --> 127     video_duration = get_video_duration(video_file)
#     129     # Query the database for Baselight collections
#     130     baselight_collection = db["baselight"]
#
# Cell In[29], line 121, in get_video_duration(video_file)
#     119 def get_video_duration(video_file):
#     120     command = ['ffmpeg', '-i', video_file, '-v', 'error', '-show_entries', 'format=duration', '-of', 'default=noprint_wrappers=1:nokey=1']
# --> 121     output = subprocess.check_output(command).decode('utf-8').strip()
#     122     return float(output)
#
# File D:\Users\stuff\anaconda3\Lib\subprocess.py:466, in check_output(timeout, *popenargs, **kwargs)
#     463         empty = b''
#     464     kwargs['input'] = empty
# --> 466 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     467            **kwargs).stdout
#
# File D:\Users\stuff\anaconda3\Lib\subprocess.py:571, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569     retcode = process.poll()
#     570     if check and retcode:
# --> 571         raise CalledProcessError(retcode, process.args,
#     572                                  output=stdout, stderr=stderr)
#     573 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['ffmpeg', '-i', 'twitch_nft_demo.mp4', '-v', 'error', '-show_entries', 'format=duration', '-of', 'default=noprint_wrappers=1:nokey=1']' returned non-zero exit status 1.

# %%
import csv
import pymongo
import subprocess

# MongoDB connection information
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
db = mongo_client["your_database_name"]

# Function to populate Baselight collection
def populate_baselight_collection(baselight_file):
    baselight_collection = db["baselight"]

    output_data = []

    for line in baselight_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        parts = line.split()
        folder = parts[0]
        frames = [int(frame) for frame in parts[1:] if frame.isdigit()]
        output_data.append({"folder": folder, "frames": frames})

    # Insert data into Baselight collection
    baselight_collection.insert_many(output_data)

def populate_xytech_collection(xytech_file):
    xytech_collection = db["xytech"]

    output_data = []

    workorder = None
    location = []
    notes = []

    for line in xytech_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        if line.startswith("Xytech Workorder"):
            if workorder is not None:  # Save previous data if any
                output_data.append({"workorder": workorder, "location": location, "notes": "\n".join(notes)})
                location = []  # Reset location for next entry
                notes = []  # Reset notes for next entry
            workorder = line.split()[-1]  # Extract workorder number
        elif line.startswith("Location:"):
            continue  # Skip Location: line
        elif line.startswith("Notes:"):
            continue  # Skip Notes: line
        else:
            # Assume it's a location path or a note
            if line.startswith("/"):  # Check if it's a location path
                location.append(line)  # Add to location list
            else:
                notes.append(line)  # Add to notes list

    # Save the last entry after loop ends
    if workorder is not None:
        output_data.append({"workorder": workorder, "location": location, "notes": "\n".join(notes)})

    # Insert data into Xytech collection
    xytech_collection.insert_many(output_data)


#proj1 script
def process_collections():
    # Query the database for Baselight collections
    baselight_collection = db["baselight"]
    cursor = baselight_collection.find({}, {"_id": 0, "folder": 1, "frames": 1})

    output_ranges = []

    # Process each document in the Baselight collection
    for document in cursor:
        currentFolder = document["folder"]
        parseline = [str(frame) for frame in document["frames"]]  # Convert frames to strings

        parseFolder = currentFolder.split("/")  # Split current folder by "/"
        if len(parseFolder) > 1:
            parseFolder.pop(1)  # Remove the second element if exists
        newFolder = "/".join(parseFolder)  # Reconstruct the folder path

        for techfile in XY_File:
            if newFolder in techfile:
                currentFolder = techfile.strip()

        tempStart = None
        tempLast = None
        for number in parseline:
            if not number.isdigit():
                continue
            number = int(number)
            if tempStart is None:
                tempStart = number
                tempLast = number
            elif number == tempLast + 1:
                tempLast = number
            else:
                if tempStart == tempLast:
                    output_ranges.append((currentFolder, tempStart))
                else:
                    output_ranges.append((currentFolder, f"{tempStart}-{tempLast}"))
                tempStart = number
                tempLast = number
        if tempStart is not None:
            if tempStart == tempLast:
                output_ranges.append((currentFolder, tempStart))
            else:
                output_ranges.append((currentFolder, f"{tempStart}-{tempLast}"))

    return output_ranges

# Function to get video duration using ffmpeg
import subprocess
import re

def get_video_duration(video_file):
    command = ['ffprobe', '-v', 'error', '-select_streams', 'v:0', '-show_entries', 'stream=duration,r_frame_rate', '-of', 'csv=p=0', video_file]
    try:
        output = subprocess.check_output(command, stderr=subprocess.STDOUT).decode('utf-8').strip()
        parts = output.split(',')
        if len(parts) > 1:
            duration_str = parts[0]
            if '/' in duration_str:
                numerator, denominator = map(float, duration_str.split('/'))
                duration = numerator / denominator
            else:
                duration = float(duration_str)
            frame_rate_str = parts[1]
            if '/' in frame_rate_str:
                numerator, denominator = map(float, frame_rate_str.split('/'))
                frame_rate = numerator / denominator
            else:
                frame_rate = float(frame_rate_str)
        else:
            duration = float(parts[0])
            frame_rate = 24  # Assuming default frame rate as 24 fps
        video_duration = duration * frame_rate
        return video_duration
    except subprocess.CalledProcessError as e:
        print(f"Error: Failed to get video duration for {video_file}.")
        print(f"Command: {' '.join(command)}")
        print(f"Error message: {e.output.decode('utf-8').strip()}")
        return None


# Function to process collections and filter frames based on video duration
def process_collectionsVideo(video_file):
    # Get video duration
    video_duration = get_video_duration(video_file)

    # Get valid frames from collections
    valid_ranges = process_collections()

    # Filter frames based on video duration
    valid_frames = []
    for folder, frames in valid_ranges:
        if isinstance(frames, int):
            if frames < video_duration:
                valid_frames.append((folder, frames))
        else:
            start_frame, end_frame = map(int, frames.split('-'))
            if start_frame < video_duration:
                valid_frames.append((folder, frames))

    # Print valid frames with timecodes for current folder
    for folder, frames in valid_frames:
        print(f"Location: {folder}")
        print("Valid Frames to fix:")
        if isinstance(frames, int):
            print(f"Frame {frames}: {frame_to_timecode(frames)}")
        else:
            start_frame, end_frame = map(int, frames.split('-'))
            print(f"Frame {start_frame} to Frame {end_frame}:")
            for frame in range(start_frame, end_frame + 1):
                print(f"  {frame_to_timecode(frame)}")
        print()
        
# Function to convert frame number to timecode
def frame_to_timecode(frame):
    fps = 24  # Assuming 24 frames per second
    total_seconds = frame / fps
    hours = int(total_seconds // 3600)
    minutes = int((total_seconds % 3600) // 60)
    seconds = int(total_seconds % 60)
    frames = int(frame % fps)
    return f"{hours:02d}:{minutes:02d}:{seconds:02d}:{frames:02d}"
            
# Paths to Baselight and Xytech files
baselight_file_path = "Baselight_export.txt"
xytech_file_path = "Xytech.txt"
video_file_path = "twitch_nft_demo.mp4"

# Open Baselight file
with open(baselight_file_path, "r") as baselight_file:
    populate_baselight_collection(baselight_file)

# Open Xytech file
with open(xytech_file_path, "r") as xytech_file:
    populate_xytech_collection(xytech_file)

# Process collections and check frames against video duration
process_collectionsVideo(video_file_path)
# Out:
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 2 to Frame 4:
#   00:00:00:02
#   00:00:00:03
#   00:00:00:04
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 31 to Frame 33:
#   00:00:01:07
#   00:00:01:08
#   00:00:01:09
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 67 to Frame 70:
#   00:00:02:19
#   00:00:02:20
#   00:00:02:21
#   00:00:02:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 122 to Frame 123:
#   00:00:05:02
#   00:00:05:03
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 155: 00:00:06:11
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1023: 00:00:42:15
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1111 to Frame 1112:
#   00:00:46:07
#   00:00:46:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1160: 00:00:48:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1201 to Frame 1205:
#   00:00:50:01
#   00:00:50:02
#   00:00:50:03
#   00:00:50:04
#   00:00:50:05
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1211 to Frame 1215:
#   00:00:50:11
#   00:00:50:12
#   00:00:50:13
#   00:00:50:14
#   00:00:50:15
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1251 to Frame 1253:
#   00:00:52:03
#   00:00:52:04
#   00:00:52:05
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1260: 00:00:52:12
#
# Location: /hpsans12/production/Dune2/reel1/VFX/Hydraulx
# Valid Frames to fix:
# Frame 1270 to Frame 1272:
#   00:00:52:22
#   00:00:52:23
#   00:00:53:00
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1302 to Frame 1303:
#   00:00:54:06
#   00:00:54:07
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1310: 00:00:54:14
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 1500: 00:01:02:12
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5000 to Frame 5002:
#   00:03:28:08
#   00:03:28:09
#   00:03:28:10
#
# Location: /hpsans15/production/Dune2/pickups/shot_1ab/1920x1080
# Valid Frames to fix:
# Frame 5010 to Frame 5014:
#   00:03:28:18
#   00:03:28:19
#   00:03:28:20
#   00:03:28:21
#   00:03:28:22
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5111: 00:03:32:23
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5122: 00:03:33:10
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5133: 00:03:33:21
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5144: 00:03:34:08
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5155: 00:03:34:19
#
# Location: /hpsans13/production/Dune2/reel1/partA/1920x1080
# Valid Frames to fix:
# Frame 5166: 00:03:35:06

# %%
import pymongo

# MongoDB connection information
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
db = mongo_client["your_database_name"]

# Function to populate Baselight collection
def populate_baselight_collection(baselight_file):
    baselight_collection = db["baselight"]

    output_data = []

    for line in baselight_file:
        data = line.strip().split()
        folder = data[0]
        frames = []
        for frame in data[1:]:
            try:
                frames.append(int(frame))
            except ValueError:
                pass
        output_data.append({"folder": folder, "frames": frames})

    # Insert data into Baselight collection
    baselight_collection.insert_many(output_data)

# Function to populate Xytech collection
# Function to populate Xytech collection
def populate_xytech_collection(xytech_file):
    xytech_collection = db["xytech"]

    output_data = []

    for line in xytech_file:
        line = line.strip()
        if not line:
            continue  # Skip empty lines
        parts = line.split()
        if len(parts) != 2:
            print(f"Ignoring invalid line in Xytech file: {line}")
            continue  # Skip lines with unexpected format
        workorder, location = parts
        output_data.append({"workorder": workorder, "location": location})

    # Insert data into Xytech collection
    xytech_collection.insert_many(output_data)

# Paths to Baselight and Xytech files
baselight_file_path = "E:/AnacodaProjects/CS467Project3/Baselight_export.txt"
xytech_file_path = "E:/AnacodaProjects/CS467Project3/Xytech.txt"

# Open Baselight file
with open(baselight_file_path, "r") as baselight_file:
    populate_baselight_collection(baselight_file)

# Open Xytech file
with open(xytech_file_path, "r") as xytech_file:
    populate_xytech_collection(xytech_file)

print("Collections populated successfully!")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 54
#      52 # Open Baselight file
#      53 with open(baselight_file_path, "r") as baselight_file:
# ---> 54     populate_baselight_collection(baselight_file)
#      56 # Open Xytech file
#      57 with open(xytech_file_path, "r") as xytech_file:
#
# Cell In[11], line 15, in populate_baselight_collection(baselight_file)
#      13 for line in baselight_file:
#      14     data = line.strip().split()
# ---> 15     folder = data[0]
#      16     frames = []
#      17     for frame in data[1:]:
#
# IndexError: list index out of range

# %%
import csv

BL_File = open("Baselight_export.txt", "r")  # Open Baselight file
#Xytech
with open("Xytech.txt") as f:
    XY_File = f.read().splitlines()
isVerbose = 0  # Set to True for verbose output

output_data = []  # List to store data for CSV export

for currentReadLine in BL_File:
    parseline = currentReadLine.split()  # Split the line
    if parseline:  # Check if the list is not empty
        currentFolder = parseline.pop(0)  # Get the current folder
        parseFolder = currentFolder.split("/")  # Split current folder by "/"
        if len(parseFolder) > 1:
            parseFolder.pop(1)  # Remove the second element if exists
        newFolder = "/".join(parseFolder)  # Reconstruct the folder path
        for techfile in XY_File:
            if newFolder in techfile:
                currentFolder = techfile.strip()
        tempStart = None
        tempLast = None
        for number in parseline:
            if not number.isdigit():
                continue
            number = int(number)
            if tempStart is None:
                tempStart = number
                tempLast = number
            elif number == tempLast + 1:
                tempLast = number
            else:
                if tempStart == tempLast:
                    output_data.append([currentFolder, tempStart])
                else:
                    output_data.append([currentFolder, f"{tempStart}-{tempLast}"])  # Concatenate range
                tempStart = number
                tempLast = number
        if tempStart is not None:
            if tempStart == tempLast:
                output_data.append([currentFolder, tempStart])
            else:
                output_data.append([currentFolder, f"{tempStart}-{tempLast}"])  # Concatenate range
    else:
        print("Empty line, skipping...")

BL_File.close()  # Close Baselight file

# Write data to CSV file
with open("output.csv", "w", newline="") as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["Producer", "Operator", "Job" , "Notes"])  # Write header
    for _ in range(2):  # Skip 4 rows
        writer.writerow([])
    writer.writerow(["Location", "frames to fix"])
    for data in output_data:
        writer.writerow(data)  # Write data

print("CSV file exported successfully!")
# Out:
# Empty line, skipping...
# CSV file exported successfully!

# %%
import csv

BL_File = open("Baselight_export.txt", "r")  # Open Baselight file
#Xytech
with open("Xytech.txt") as f:
    XY_File = f.read().splitlines()
    # Extract producer, operator, job, and notes from Xytech file
    producer, operator, job, notes = None, None, None, None
    for line in XY_File:
        if line.startswith("Producer:"):
            producer = line.split(':')[1].strip()
        elif line.startswith("Operator:"):
            operator = line.split(':')[1].strip()
        elif line.startswith("Job:"):
            job = line.split(':')[1].strip()
        elif line == "Notes:":
            notes_index = XY_File.index(line)
            notes = '\n'.join(XY_File[notes_index + 1:]).strip()
isVerbose = 0  # Set to True for verbose output

output_data = []  # List to store data for CSV export

for currentReadLine in BL_File:
    parseline = currentReadLine.split()  # Split the line
    if parseline:  # Check if the list is not empty
        currentFolder = parseline.pop(0)  # Get the current folder
        parseFolder = currentFolder.split("/")  # Split current folder by "/"
        if len(parseFolder) > 1:
            parseFolder.pop(1)  # Remove the second element if exists
        newFolder = "/".join(parseFolder)  # Reconstruct the folder path
        for techfile in XY_File:
            if newFolder in techfile:
                currentFolder = techfile.strip()
        tempStart = None
        tempLast = None
        for number in parseline:
            if not number.isdigit():
                continue
            number = int(number)
            if tempStart is None:
                tempStart = number
                tempLast = number
            elif number == tempLast + 1:
                tempLast = number
            else:
                if tempStart == tempLast:
                    output_data.append([currentFolder, tempStart])
                else:
                    output_data.append([currentFolder, f"{tempStart}-{tempLast}"])  # Concatenate range
                tempStart = number
                tempLast = number
        if tempStart is not None:
            if tempStart == tempLast:
                output_data.append([currentFolder, tempStart])
            else:
                output_data.append([currentFolder, f"{tempStart}-{tempLast}"])  # Concatenate range
    else:
        print("Empty line, skipping...")

BL_File.close()  # Close Baselight file

# Write data to CSV file
with open("output.csv", "w", newline="") as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(["Producer", "Operator", "Job" , "Notes"])  # Write header
    writer.writerow([producer, operator, job , notes])  # Write header
    for _ in range(2):  # Skip 4 rows
        writer.writerow([])
    writer.writerow(["Location", "frames to fix"])
    for data in output_data:
        writer.writerow(data)  # Write data

print("CSV file exported successfully!")
# Out:
# Empty line, skipping...
# CSV file exported successfully!
